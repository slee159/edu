# %% [markdown]
# <a href="https://colab.research.google.com/github/slee159/edu/blob/master/19%EC%9D%BC%EC%B0%A8_200821_(1)_%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# http://seaborn.pydata.org/tutorial.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid") # 스타일은 darkgrid, whitegrid, dark, white, ticks이 있음!

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x="total_bill", y="tip", data=tips)

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips)
# smoker 기준 색깔 비교

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", style="smoker", data=tips)
# smoker 기준 마커 모양 비교

# %%
sns.relplot(x="total_bill", y="tip", hue="smoker", style="time", data=tips)
# smoker 기준 / time 기준

# %%
sns.relplot(x="total_bill", y="tip", hue="size", data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="size", palette="ch:r=-.5,l=.75", data=tips);

# %%
# seaborn 내 palette 확인해보기
sns.palplot(sns.cubehelix_palette())

# %%
sns.relplot(x="total_bill", y="tip", size="size", data=tips)
# size 기준 마커의 크기 비교

# %%
sns.relplot(x="total_bill", y="tip", size="size", sizes=(15, 200), data=tips)

# %%
df = pd.DataFrame(dict(time=np.arange(500), value=np.random.randn(500).cumsum()))
df.head()
# column이 time인 것 / value에는 난수값 / cumsum은 누적 합..!
# Out:
#    time     value
# 0     0  0.191262
# 1     1  0.296514
# 2     2  1.506656
# 3     3  1.361350
# 4     4  0.313097

# %%
g = sns.relplot(x="time", y="value", kind="line", data=df)
# kind에 line을 설정하지 않으면 산점도로만 출력됨

# %%
df = pd.DataFrame(np.random.randn(500, 2).cumsum(axis=0), columns=["x", "y"])
df.head()
# Out:
#           x         y
# 0  0.557300  1.779154
# 1 -0.174327  1.586684
# 2 -2.028843  0.374142
# 3 -3.820299 -1.165514
# 4 -3.776528 -1.124605

# %%
sns.relplot(x="x", y="y", kind="line", data=df)
# sort = False를 하지 않으면, x값이 작은 값부터 큰 값까지 자동으로 정렬되어 깔끔한 그래프가 나온다

# %%
sns.relplot(x="x", y="y", sort=False, kind="line", data=df)

# %%
fmri = sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x="timepoint", y="signal", kind="line", data=fmri)
